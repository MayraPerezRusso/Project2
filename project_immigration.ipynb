# %%
API =  "a047c1ad12d8044f2fddca367594866cf68b9259"
import pandas as pd
import numpy as np
from census import Census

# %%
c = Census(API, 2017)
data = c.acs5.get(("NAME","B05006_001E"), {'for': 'county:*'})
data
# Out:
# [{'NAME': 'Corozal Municipio, Puerto Rico',
#   'B05006_001E': None,
#   'state': '72',
#   'county': '047'},
#  {'NAME': 'Maunabo Municipio, Puerto Rico',
#   'B05006_001E': None,
#   'state': '72',
#   'county': '095'},
#  {'NAME': 'Peñuelas Municipio, Puerto Rico',
#   'B05006_001E': None,
#   'state': '72',
#   'county': '111'},
#  {'NAME': 'Ponce Municipio, Puerto Rico',
#   'B05006_001E': None,
#   'state': '72',
#   'county': '113'},
#  {'NAME': 'San Sebastián Municipio, Puerto Rico',
#   'B05006_001E': None,
#   'state': '72',
#   'county': '131'},
#  {'NAME': 'Toa Alta Municipio, Puerto Rico',
#   'B05006_001E': None,
#   'state': '72',
#   'county': '135'},
#  {'NAME': 'Toa Baja Municipio, Puerto Rico',
#   'B05006_001E': None,
#   'state': '72',
#   'county': '137'},
#  {'NAME': 'Vieques Municipio, Puerto Rico',
#   'B05006_001E': None,
#   'state': '72',
#   'county': '147'},
#  {'NAME': 'Yabucoa Municipio, Puerto Rico',
#   'B05006_001E': None,
#   'state': '72',
# ...
