# %%
import pandas as pd
import numpy as np

file_to_load = "Resources/health_data_city.csv"

full_data_pd = pd.read_csv(file_to_load)

full_data_pd.head()

#Full Data from csv
# Out:
#                   Indicator Category  \
# 0  Behavioral Health/Substance Abuse
# 1  Behavioral Health/Substance Abuse
# 2  Behavioral Health/Substance Abuse
# 3  Behavioral Health/Substance Abuse
# 4  Behavioral Health/Substance Abuse
#
#                                            Indicator  \
# 0  Opioid-Related Unintentional Drug Overdose Mor...
# 1  Opioid-Related Unintentional Drug Overdose Mor...
# 2  Opioid-Related Unintentional Drug Overdose Mor...
# 3  Opioid-Related Unintentional Drug Overdose Mor...
# 4  Opioid-Related Unintentional Drug Overdose Mor...
#
#                  Shortened Indicator Name Shortened Indicator Name (Graph)  \
# 0  Opioid-Related Overdose Mortality Rate                              NaN
# 1  Opioid-Related Overdose Mortality Rate                              NaN
# 2  Opioid-Related Overdose Mortality Rate                              NaN
# 3  Opioid-Related Overdose Mortality Rate                              NaN
# ...

# %%
unique_place = full_data_pd["Place"].unique()
#Calculated total number and list of cities 30 + us totals

# %%
number_of_unique_places = len(unique_place)
print(number_of_unique_places)
# Out:
# 31

# %%
places_list = full_data_pd.Place.unique()

# %%
places_list
# Out:
# array(['Boston, MA', 'Columbus, OH', 'Denver, CO',
#        'Fort Worth (Tarrant County), TX', 'Houston, TX',
#        'Kansas City, MO', 'Las Vegas (Clark County), NV',
#        'Los Angeles, CA', 'Miami (Miami-Dade County), FL',
#        'Minneapolis, MN', 'Oakland (Alameda County), CA', 'Phoenix, AZ',
#        'Portland (Multnomah County), OR', 'San Antonio, TX',
#        'San Diego County, CA', 'U.S. Total', 'Washington, DC',
#        'Baltimore, MD', 'Charlotte, NC', 'Chicago, IL', 'Detroit, MI',
#        'Indianapolis (Marion County), IN', 'Long Beach, CA',
#        'New York City, NY', 'Philadelphia, PA', 'San Jose, CA',
#        'Seattle, WA', 'San Francisco, CA', 'Cleveland, OH', 'Austin, TX',
#        'Dallas, TX'], dtype=object)

# %%
clean_data_pd = full_data_pd.drop(['Indicator', 'Shortened Indicator Name (Graph)','BCHC Requested Methodology','Source','Methods','Notes','90% Confidence Level - Low','90% Confidence Level - High','95% Confidence Level - Low','95% Confidence Level - High'], axis=1)

# %%
clean_data_pd = clean_data_pd.rename(columns={"Indicator Category":"Category", "Shortened Indicator Name":"Short_indicator", "Race/Ethnicity":"Ethnicity"})

# %%
clean_data_pd.head()
# Out:
#                             Category                         Short_indicator  \
# 0  Behavioral Health/Substance Abuse  Opioid-Related Overdose Mortality Rate
# 1  Behavioral Health/Substance Abuse  Opioid-Related Overdose Mortality Rate
# 2  Behavioral Health/Substance Abuse  Opioid-Related Overdose Mortality Rate
# 3  Behavioral Health/Substance Abuse  Opioid-Related Overdose Mortality Rate
# 4  Behavioral Health/Substance Abuse  Opioid-Related Overdose Mortality Rate
#
#    Year     Sex Ethnicity Value       Place
# 0  2011    Both       All   3.9  Boston, MA
# 1  2011    Both     White   7.1  Boston, MA
# 2  2011  Female       All   3.1  Boston, MA
# 3  2011    Male       All   4.8  Boston, MA
# 4  2012    Both       All   3.6  Boston, MA

# %%
unique_factors = clean_data_pd["Category"].unique()
#Calculated total number of factors and listed them

# %%
number_of_unique_factors = len(unique_factors)
print(number_of_unique_factors)
# Out:
# 13

# %%
factor_list = clean_data_pd.Category.unique()

# %%
factor_list
# Out:
# array(['Behavioral Health/Substance Abuse', 'Cancer', 'Chronic Disease',
#        'Demographics', 'Environment', 'Food Safety', 'HIV/AIDS',
#        'Infectious Disease', 'Injury/Violence',
#        'Life Expectancy and Death Rate (Overall)',
#        'Maternal and Child Health', 'Sexually Transmitted Infections',
#        'Social and Economic Factors'], dtype=object)

# %%
unique_indicators = clean_data_pd["Short_indicator"].unique()
#Calculated total number of indicators and listed them

# %%
number_of_unique_indicators = len(unique_indicators)
print(number_of_unique_indicators)
# Out:
# 64

# %%
indicator_list = clean_data_pd.Short_indicator.unique()
indicator_list
# Out:
# array(['Opioid-Related Overdose Mortality Rate', 'Adult Binge Drinking',
#        'Teen Binge Drinking', 'All Types of Cancer Mortality Rate',
#        'Female Breast Cancer Mortality Rate',
#        'Lung Cancer Mortality Rate',
#        'Asthma Emergency Department Visit Rate',
#        'Diabetes Mortality Rate', 'Heart Disease Mortality Rate',
#        'Adult Obesity', 'Adult Smoking', 'Adult Physical Activity Levels',
#        'Teen Obesity', 'Teen Smoking', 'Teen Physical Activity Levels',
#        'Foreign Born Population', 'Aging Population', 'Youth Population',
#        'Disability', 'English Speaking Population',
#        'Spanish Speaking Population', 'Race/Ethnicity', 'Sex',
#        'Total Population', 'Bike Score', 'Transit Score', 'Walkability',
#        "Children's Blood Lead Levels", 'Salmonella Infections',
#        'E.coli Infections', 'AIDS Diagnoses Rate', 'HIV Diagnoses Rate',
#        'HIV-Related Mortality Rate', 'Persons Living with HIV/AIDS Rate',
# ...

# %%
clean_test = clean_data_pd[clean_data_pd["Category"]!="Behavioral Health/Substance Abuse"]
clean_test.head()
# Out:
#      Category                     Short_indicator  Year   Sex Ethnicity  \
# 1481   Cancer  All Types of Cancer Mortality Rate  2012  Both       All
# 1482   Cancer  All Types of Cancer Mortality Rate  2010  Both       All
# 1483   Cancer  All Types of Cancer Mortality Rate  2010  Both  Asian/PI
# 1484   Cancer  All Types of Cancer Mortality Rate  2010  Both     Black
# 1485   Cancer  All Types of Cancer Mortality Rate  2010  Both  Hispanic
#
#       Value          Place
# 1481  213.9  Baltimore, MD
# 1482  184.1     Boston, MA
# 1483    156     Boston, MA
# 1484  221.8     Boston, MA
# 1485  116.7     Boston, MA

# %%
only_chronic_pd = clean_data_pd[clean_data_pd["Category"]=="Chronic Disease"]
only_chronic_pd.head()
# Out:
#              Category                         Short_indicator  Year   Sex  \
# 4219  Chronic Disease  Asthma Emergency Department Visit Rate  2010  Both
# 4220  Chronic Disease  Asthma Emergency Department Visit Rate  2010  Both
# 4221  Chronic Disease  Asthma Emergency Department Visit Rate  2010  Both
# 4222  Chronic Disease  Asthma Emergency Department Visit Rate  2010  Both
# 4223  Chronic Disease  Asthma Emergency Department Visit Rate  2010  Both
#
#      Ethnicity  Value       Place
# 4219       All  113.6  Boston, MA
# 4220  Asian/PI     29  Boston, MA
# 4221     Black  242.2  Boston, MA
# 4222  Hispanic  140.8  Boston, MA
# 4223     Other   10.7  Boston, MA

# %%
all_ethnicity_pd = only_chronic_pd[only_chronic_pd["Ethnicity"]=="All"]
all_ethnicity_pd.head()
# Out:
#              Category                         Short_indicator  Year     Sex  \
# 4219  Chronic Disease  Asthma Emergency Department Visit Rate  2010    Both
# 4225  Chronic Disease  Asthma Emergency Department Visit Rate  2010  Female
# 4226  Chronic Disease  Asthma Emergency Department Visit Rate  2010    Male
# 4227  Chronic Disease  Asthma Emergency Department Visit Rate  2011    Both
# 4233  Chronic Disease  Asthma Emergency Department Visit Rate  2011  Female
#
#      Ethnicity  Value       Place
# 4219       All  113.6  Boston, MA
# 4225       All    114  Boston, MA
# 4226       All  111.6  Boston, MA
# 4227       All  104.7  Boston, MA
# 4233       All  106.6  Boston, MA

# %%
unique_indicators = all_ethnicity_pd["Short_indicator"].unique()

number_of_unique_indicators = len(unique_indicators)
print(number_of_unique_indicators)

factor_list = all_ethnicity_pd.Short_indicator.unique()

print(factor_list)
#narrowd data down to only Chronic Disease factors (related to health), 
#from there calculated total number of indicators and listed them
# Out:
# 9
# ['Asthma Emergency Department Visit Rate' 'Diabetes Mortality Rate'
#  'Heart Disease Mortality Rate' 'Adult Obesity' 'Adult Smoking'
#  'Adult Physical Activity Levels' 'Teen Obesity' 'Teen Smoking'
#  'Teen Physical Activity Levels']

# %%
clean_test_2 = all_ethnicity_pd[all_ethnicity_pd["Short_indicator"]!="Asthma Emergency Department Visit Rate"]
clean_test_2.head()
# Out:
#              Category          Short_indicator  Year     Sex Ethnicity Value  \
# 4543  Chronic Disease  Diabetes Mortality Rate  2010    Both       All  12.9
# 4549  Chronic Disease  Diabetes Mortality Rate  2010  Female       All   9.5
# 4550  Chronic Disease  Diabetes Mortality Rate  2010    Male       All  17.1
# 4551  Chronic Disease  Diabetes Mortality Rate  2011    Both       All  19.5
# 4557  Chronic Disease  Diabetes Mortality Rate  2011  Female       All  16.7
#
#            Place
# 4543  Boston, MA
# 4549  Boston, MA
# 4550  Boston, MA
# 4551  Boston, MA
# 4557  Boston, MA

# %%
clean_test_3 = clean_test_2[clean_test_2["Short_indicator"]!="Adult Smoking"]
clean_test_3.head()
# Out:
#              Category          Short_indicator  Year     Sex Ethnicity Value  \
# 4543  Chronic Disease  Diabetes Mortality Rate  2010    Both       All  12.9
# 4549  Chronic Disease  Diabetes Mortality Rate  2010  Female       All   9.5
# 4550  Chronic Disease  Diabetes Mortality Rate  2010    Male       All  17.1
# 4551  Chronic Disease  Diabetes Mortality Rate  2011    Both       All  19.5
# 4557  Chronic Disease  Diabetes Mortality Rate  2011  Female       All  16.7
#
#            Place
# 4543  Boston, MA
# 4549  Boston, MA
# 4550  Boston, MA
# 4551  Boston, MA
# 4557  Boston, MA

# %%
clean_test_4 = clean_test_3[clean_test_3["Short_indicator"]!="Adult Smoking"]
clean_test_4.head()
# Out:
#              Category          Short_indicator  Year     Sex Ethnicity Value  \
# 4543  Chronic Disease  Diabetes Mortality Rate  2010    Both       All  12.9
# 4549  Chronic Disease  Diabetes Mortality Rate  2010  Female       All   9.5
# 4550  Chronic Disease  Diabetes Mortality Rate  2010    Male       All  17.1
# 4551  Chronic Disease  Diabetes Mortality Rate  2011    Both       All  19.5
# 4557  Chronic Disease  Diabetes Mortality Rate  2011  Female       All  16.7
#
#            Place
# 4543  Boston, MA
# 4549  Boston, MA
# 4550  Boston, MA
# 4551  Boston, MA
# 4557  Boston, MA

# %%
clean_test_5 = clean_test_4[clean_test_4["Short_indicator"]!="Teen Obesity"]
clean_test_5.head()
# Out:
#              Category          Short_indicator  Year     Sex Ethnicity Value  \
# 4543  Chronic Disease  Diabetes Mortality Rate  2010    Both       All  12.9
# 4549  Chronic Disease  Diabetes Mortality Rate  2010  Female       All   9.5
# 4550  Chronic Disease  Diabetes Mortality Rate  2010    Male       All  17.1
# 4551  Chronic Disease  Diabetes Mortality Rate  2011    Both       All  19.5
# 4557  Chronic Disease  Diabetes Mortality Rate  2011  Female       All  16.7
#
#            Place
# 4543  Boston, MA
# 4549  Boston, MA
# 4550  Boston, MA
# 4551  Boston, MA
# 4557  Boston, MA

# %%
clean_test_6 = clean_test_5[clean_test_5["Short_indicator"]!="Teen Smoking"]
clean_test_6.head()
# Out:
#              Category          Short_indicator  Year     Sex Ethnicity Value  \
# 4543  Chronic Disease  Diabetes Mortality Rate  2010    Both       All  12.9
# 4549  Chronic Disease  Diabetes Mortality Rate  2010  Female       All   9.5
# 4550  Chronic Disease  Diabetes Mortality Rate  2010    Male       All  17.1
# 4551  Chronic Disease  Diabetes Mortality Rate  2011    Both       All  19.5
# 4557  Chronic Disease  Diabetes Mortality Rate  2011  Female       All  16.7
#
#            Place
# 4543  Boston, MA
# 4549  Boston, MA
# 4550  Boston, MA
# 4551  Boston, MA
# 4557  Boston, MA

# %%
clean_test_7 = clean_test_6[clean_test_6["Short_indicator"]!="Teen Physical Activity Levels"]
clean_test_7.head()
# Out:
#              Category          Short_indicator  Year     Sex Ethnicity Value  \
# 4543  Chronic Disease  Diabetes Mortality Rate  2010    Both       All  12.9
# 4549  Chronic Disease  Diabetes Mortality Rate  2010  Female       All   9.5
# 4550  Chronic Disease  Diabetes Mortality Rate  2010    Male       All  17.1
# 4551  Chronic Disease  Diabetes Mortality Rate  2011    Both       All  19.5
# 4557  Chronic Disease  Diabetes Mortality Rate  2011  Female       All  16.7
#
#            Place
# 4543  Boston, MA
# 4549  Boston, MA
# 4550  Boston, MA
# 4551  Boston, MA
# 4557  Boston, MA

# %%
clean_test_7
#narrowed it down once more to 4 indicators that interested us for this study: 
#Diabetes Mortality Rate, Heart Disease Mortality Rate,Adult Obesity, Adult Physical Activity Levels
# Out:
#              Category                 Short_indicator  Year     Sex Ethnicity  \
# 4543  Chronic Disease         Diabetes Mortality Rate  2010    Both       All
# 4549  Chronic Disease         Diabetes Mortality Rate  2010  Female       All
# 4550  Chronic Disease         Diabetes Mortality Rate  2010    Male       All
# 4551  Chronic Disease         Diabetes Mortality Rate  2011    Both       All
# 4557  Chronic Disease         Diabetes Mortality Rate  2011  Female       All
# 4558  Chronic Disease         Diabetes Mortality Rate  2011    Male       All
# 4559  Chronic Disease         Diabetes Mortality Rate  2012    Both       All
# 4565  Chronic Disease         Diabetes Mortality Rate  2012  Female       All
# 4566  Chronic Disease         Diabetes Mortality Rate  2012    Male       All
# 4567  Chronic Disease         Diabetes Mortality Rate  2013    Both       All
# 4573  Chronic Disease         Diabetes Mortality Rate  2013  Female       All
# ...

# %%
sorted_df = clean_test_7.sort_values(['Place', 'Short_indicator' , 'Year' ,'Sex'])

# %%
sorted_df.head()
# Out:
#              Category Short_indicator  Year     Sex Ethnicity Value  \
# 6670  Chronic Disease   Adult Obesity  2010    Both       All  29.2
# 6673  Chronic Disease   Adult Obesity  2010  Female       All  32.8
# 6674  Chronic Disease   Adult Obesity  2010    Male       All  25.1
# 6675  Chronic Disease   Adult Obesity  2011    Both       All  37.3
# 6678  Chronic Disease   Adult Obesity  2011  Female       All  39.4
#
#               Place
# 6670  Baltimore, MD
# 6673  Baltimore, MD
# 6674  Baltimore, MD
# 6675  Baltimore, MD
# 6678  Baltimore, MD

# %%
clean_sorted_data_pd = sorted_df.drop(['Category', 'Ethnicity'], axis=1)

# %%
clean_sorted_data_pd.reset_index(drop=True, inplace=True)

# %%
clean_sorted_data_pd.head()
# Out:
#   Short_indicator  Year     Sex Value          Place
# 0   Adult Obesity  2010    Both  29.2  Baltimore, MD
# 1   Adult Obesity  2010  Female  32.8  Baltimore, MD
# 2   Adult Obesity  2010    Male  25.1  Baltimore, MD
# 3   Adult Obesity  2011    Both  37.3  Baltimore, MD
# 4   Adult Obesity  2011  Female  39.4  Baltimore, MD

# %%
#This is the final sorted data frame. 30 cities + US total.
#Dataframe is sorted by city, year
#There are 4 health factors we are looking at Obesity, Physical Activity, Diabetes and Heart Disease
#There is data availble for male or female or both
#Dataset is not complete for all years and all indicators

# %%
print(clean_sorted_data_pd.to_string())
# Out:
#                      Short_indicator  Year     Sex   Value                             Place
# 0                      Adult Obesity  2010    Both    29.2                     Baltimore, MD
# 1                      Adult Obesity  2010  Female    32.8                     Baltimore, MD
# 2                      Adult Obesity  2010    Male    25.1                     Baltimore, MD
# 3                      Adult Obesity  2011    Both    37.3                     Baltimore, MD
# 4                      Adult Obesity  2011  Female    39.4                     Baltimore, MD
# 5                      Adult Obesity  2011    Male      35                     Baltimore, MD
# 6                      Adult Obesity  2012    Both    30.7                     Baltimore, MD
# 7                      Adult Obesity  2012  Female    34.2                     Baltimore, MD
# 8                      Adult Obesity  2012    Male      27                     Baltimore, MD
# ...
